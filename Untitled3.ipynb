# %%
import jax
import jax.numpy as jnp

# %%
def f(x):
  return jnp.sum(x**2)

jax.grad(f([0,1,2,3,4]))
squares_dx = jax.grad(f)

x = jnp.asarray([1.0, 2.0, 3.0, 4.0])

print(f(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-22d53c69c776> in <cell line: 4>()
#       2   return jnp.sum(x**2)
#       3
# ----> 4 jax.grad(f([0,1,2,3,4]))
#       5 squares_dx = jax.grad(f)
#       6
#
# <ipython-input-10-22d53c69c776> in f(x)
#       1 def f(x):
# ----> 2   return jnp.sum(x**2)
#       3
#       4 jax.grad(f([0,1,2,3,4]))
#       5 squares_dx = jax.grad(f)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
