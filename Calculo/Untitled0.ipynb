# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %%
def f(x): return x**2

# %%
i = [i for i in range(0,9)]

n = 4

dx = (i[-1]- i[0])/n
i,dx
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8], 2.0)

# %%
# Al = 112

f1 = [f(x) for x in i]
df = pd.DataFrame(
    {"x": i, "y":f1}
    )
sn.pointplot(data=df, x="x", y="y")

for i in range(i[0], i[-1], dx):
  print(i,f(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-a5d9f0c3e6ef> in <cell line: 9>()
#       7 sn.pointplot(data=df, x="x", y="y")
#       8
# ----> 9 for i in range(i[0], i[-1], dx):
#      10   print(i,f(i))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
# Ar = 240
sum = 0
for j in range(i[1],8,2):
  sum += f(j)
  print(f"{j}-{sum}")
areaL = sum
areaL, 2*sum
# Out:
# 1-1
# 3-10
# 5-35
# 7-84
# (84, 168)
