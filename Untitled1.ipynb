# %%
import seaborn as sns

# %%
def f(x):
  return -4-2*x

# %%
import pandas as pd

dominio = [i for i in range(1,10)]

imagem = [f(i) for i in range(1,10)]

df = pd.DataFrame({
    "dominio": dominio,
    "imagem": imagem
})

# %%
sns.lineplot(data=df)
# Out:
# <Axes: >
